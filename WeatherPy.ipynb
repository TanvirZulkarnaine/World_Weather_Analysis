# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(coordinate[0], coordinate[1])

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 606

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Create url.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | faya
# Processing Record 2 of Set 1 | pishva
# Processing Record 3 of Set 1 | luanda
# Processing Record 4 of Set 1 | ileza
# Processing Record 5 of Set 1 | cockburn town
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | mikhaylovka
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | derzhavinsk
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | adrar
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | bridlington
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | guerrero negro
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | yamada
# Processing Record 21 of Set 1 | savannah bight
# Processing Record 22 of Set 1 | klaksvik
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | almaznyy
# Processing Record 26 of Set 1 | lagoa
# Processing Record 27 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 1 | pangai
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | krathum baen
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | fort nelson
# Processing Record 39 of Set 1 | copacabana
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 1 | khandyga
# Processing Record 46 of Set 1 | carballo
# Processing Record 47 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 48 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 1 | geraldton
# Processing Record 50 of Set 1 | maniitsoq
# Processing Record 1 of Set 2 | nishihara
# Processing Record 2 of Set 2 | fulitun
# City not found. Skipping...
# Processing Record 3 of Set 2 | opuwo
# Processing Record 4 of Set 2 | salinas
# Processing Record 5 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 2 | baturaja
# Processing Record 7 of Set 2 | komatipoort
# Processing Record 8 of Set 2 | port lincoln
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | labrea
# Processing Record 11 of Set 2 | zacualtipan
# Processing Record 12 of Set 2 | sakaiminato
# Processing Record 13 of Set 2 | panzhihua
# Processing Record 14 of Set 2 | asau
# Processing Record 15 of Set 2 | hasaki
# Processing Record 16 of Set 2 | hamilton
# Processing Record 17 of Set 2 | mataura
# Processing Record 18 of Set 2 | chicama
# Processing Record 19 of Set 2 | sabang
# Processing Record 20 of Set 2 | karratha
# Processing Record 21 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 2 | juneau
# Processing Record 23 of Set 2 | chumikan
# Processing Record 24 of Set 2 | tshikapa
# Processing Record 25 of Set 2 | marystown
# Processing Record 26 of Set 2 | ajdabiya
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | deogarh
# Processing Record 29 of Set 2 | qitaihe
# Processing Record 30 of Set 2 | puerto palomas
# Processing Record 31 of Set 2 | tasiilaq
# Processing Record 32 of Set 2 | saldanha
# Processing Record 33 of Set 2 | sinnamary
# Processing Record 34 of Set 2 | aksu
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | norman wells
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | bluff
# Processing Record 39 of Set 2 | gornyy
# Processing Record 40 of Set 2 | torbay
# Processing Record 41 of Set 2 | port elizabeth
# Processing Record 42 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 2 | mikuni
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | quatre cocos
# Processing Record 46 of Set 2 | bosaso
# Processing Record 47 of Set 2 | salalah
# Processing Record 48 of Set 2 | shingu
# Processing Record 49 of Set 2 | pitimbu
# Processing Record 50 of Set 2 | bethel
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | vila
# Processing Record 3 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 4 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 3 | nantucket
# Processing Record 6 of Set 3 | varhaug
# Processing Record 7 of Set 3 | katsuura
# Processing Record 8 of Set 3 | japura
# Processing Record 9 of Set 3 | staryy biser
# City not found. Skipping...
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | santa cruz
# Processing Record 12 of Set 3 | kodiak
# Processing Record 13 of Set 3 | baculin
# Processing Record 14 of Set 3 | ayan
# Processing Record 15 of Set 3 | dingle
# Processing Record 16 of Set 3 | hwange
# Processing Record 17 of Set 3 | kahului
# Processing Record 18 of Set 3 | khatanga
# Processing Record 19 of Set 3 | chandler
# Processing Record 20 of Set 3 | daru
# Processing Record 21 of Set 3 | yerbogachen
# Processing Record 22 of Set 3 | kindu
# Processing Record 23 of Set 3 | barrow
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | trat
# Processing Record 26 of Set 3 | sabzevar
# Processing Record 27 of Set 3 | east london
# Processing Record 28 of Set 3 | fortuna
# Processing Record 29 of Set 3 | nikolskoye
# Processing Record 30 of Set 3 | mocuba
# Processing Record 31 of Set 3 | dunhua
# Processing Record 32 of Set 3 | georgetown
# Processing Record 33 of Set 3 | thinadhoo
# Processing Record 34 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 3 | phatthalung
# Processing Record 36 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 3 | burica
# City not found. Skipping...
# Processing Record 38 of Set 3 | ostrovnoy
# Processing Record 39 of Set 3 | lerwick
# Processing Record 40 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 3 | stromness
# Processing Record 42 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 3 | sinjah
# City not found. Skipping...
# Processing Record 44 of Set 3 | airai
# Processing Record 45 of Set 3 | san policarpo
# Processing Record 46 of Set 3 | parana
# Processing Record 47 of Set 3 | cape town
# Processing Record 48 of Set 3 | alpena
# Processing Record 49 of Set 3 | goderich
# Processing Record 50 of Set 3 | coquimbo
# Processing Record 1 of Set 4 | victoria
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | hovd
# Processing Record 4 of Set 4 | umm lajj
# Processing Record 5 of Set 4 | bredasdorp
# Processing Record 6 of Set 4 | honningsvag
# Processing Record 7 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 4 | severo-kurilsk
# Processing Record 9 of Set 4 | cidreira
# Processing Record 10 of Set 4 | lebu
# Processing Record 11 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 4 | neuquen
# Processing Record 13 of Set 4 | farafangana
# Processing Record 14 of Set 4 | turukhansk
# Processing Record 15 of Set 4 | kamir
# Processing Record 16 of Set 4 | bengkulu
# Processing Record 17 of Set 4 | nome
# Processing Record 18 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 4 | thompson
# Processing Record 20 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 4 | tolaga bay
# Processing Record 22 of Set 4 | san cristobal
# Processing Record 23 of Set 4 | shu
# Processing Record 24 of Set 4 | kapaa
# Processing Record 25 of Set 4 | mount gambier
# Processing Record 26 of Set 4 | ahipara
# Processing Record 27 of Set 4 | sao filipe
# Processing Record 28 of Set 4 | provideniya
# Processing Record 29 of Set 4 | usinsk
# Processing Record 30 of Set 4 | yar-sale
# Processing Record 31 of Set 4 | los llanos de aridane
# Processing Record 32 of Set 4 | college
# Processing Record 33 of Set 4 | calabozo
# Processing Record 34 of Set 4 | kavieng
# Processing Record 35 of Set 4 | elko
# Processing Record 36 of Set 4 | namatanai
# Processing Record 37 of Set 4 | longyearbyen
# Processing Record 38 of Set 4 | muisne
# Processing Record 39 of Set 4 | miri
# Processing Record 40 of Set 4 | buala
# Processing Record 41 of Set 4 | pevek
# Processing Record 42 of Set 4 | hami
# Processing Record 43 of Set 4 | virginia beach
# Processing Record 44 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 4 | taua
# Processing Record 46 of Set 4 | caravelas
# Processing Record 47 of Set 4 | lasa
# Processing Record 48 of Set 4 | trapani
# Processing Record 49 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 4 | lomza
# Processing Record 1 of Set 5 | lompoc
# Processing Record 2 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 5 | nanortalik
# Processing Record 4 of Set 5 | krynychky
# Processing Record 5 of Set 5 | atar
# Processing Record 6 of Set 5 | dakar
# Processing Record 7 of Set 5 | templin
# Processing Record 8 of Set 5 | sarangani
# Processing Record 9 of Set 5 | kaitangata
# Processing Record 10 of Set 5 | gueret
# Processing Record 11 of Set 5 | sobolevo
# Processing Record 12 of Set 5 | the valley
# Processing Record 13 of Set 5 | dayong
# Processing Record 14 of Set 5 | rio grande
# Processing Record 15 of Set 5 | abha
# Processing Record 16 of Set 5 | omboue
# Processing Record 17 of Set 5 | ribeira grande
# Processing Record 18 of Set 5 | sitka
# Processing Record 19 of Set 5 | malanje
# Processing Record 20 of Set 5 | goulburn
# Processing Record 21 of Set 5 | springbok
# Processing Record 22 of Set 5 | kruisfontein
# Processing Record 23 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 24 of Set 5 | grand gaube
# Processing Record 25 of Set 5 | soto la marina
# Processing Record 26 of Set 5 | roma
# Processing Record 27 of Set 5 | geelong
# Processing Record 28 of Set 5 | panaba
# Processing Record 29 of Set 5 | hithadhoo
# Processing Record 30 of Set 5 | krasnoselkup
# Processing Record 31 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 32 of Set 5 | nikki
# Processing Record 33 of Set 5 | bathsheba
# Processing Record 34 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 5 | urucara
# Processing Record 36 of Set 5 | phetchabun
# Processing Record 37 of Set 5 | torres
# Processing Record 38 of Set 5 | ulaangom
# Processing Record 39 of Set 5 | ardakan
# Processing Record 40 of Set 5 | santa isabel do rio negro
# Processing Record 41 of Set 5 | tortoli
# Processing Record 42 of Set 5 | cap malheureux
# Processing Record 43 of Set 5 | minot
# Processing Record 44 of Set 5 | umm jarr
# City not found. Skipping...
# Processing Record 45 of Set 5 | hobyo
# Processing Record 46 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 5 | porangatu
# Processing Record 49 of Set 5 | saint george
# Processing Record 50 of Set 5 | boissevain
# Processing Record 1 of Set 6 | bukama
# Processing Record 2 of Set 6 | inhambane
# Processing Record 3 of Set 6 | daura
# Processing Record 4 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 6 | lesnoy
# Processing Record 6 of Set 6 | yeppoon
# Processing Record 7 of Set 6 | surt
# Processing Record 8 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 6 | vila velha
# Processing Record 10 of Set 6 | narsaq
# Processing Record 11 of Set 6 | lima
# Processing Record 12 of Set 6 | stamsund
# City not found. Skipping...
# Processing Record 13 of Set 6 | novopokrovka
# Processing Record 14 of Set 6 | melfort
# Processing Record 15 of Set 6 | porto novo
# Processing Record 16 of Set 6 | ouegoa
# Processing Record 17 of Set 6 | blackwater
# Processing Record 18 of Set 6 | kitui
# Processing Record 19 of Set 6 | marsh harbour
# Processing Record 20 of Set 6 | cabo san lucas
# Processing Record 21 of Set 6 | astoria
# Processing Record 22 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 6 | porto santo
# Processing Record 24 of Set 6 | aklavik
# Processing Record 25 of Set 6 | antalaha
# Processing Record 26 of Set 6 | risti
# Processing Record 27 of Set 6 | ukiah
# Processing Record 28 of Set 6 | salina
# Processing Record 29 of Set 6 | lata
# Processing Record 30 of Set 6 | mweka
# Processing Record 31 of Set 6 | marseille
# Processing Record 32 of Set 6 | pushkinskiye gory
# Processing Record 33 of Set 6 | bambous virieux
# Processing Record 34 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 6 | hambantota
# Processing Record 36 of Set 6 | bougouni
# Processing Record 37 of Set 6 | kirovskiy
# Processing Record 38 of Set 6 | axim
# Processing Record 39 of Set 6 | pangnirtung
# Processing Record 40 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 6 | mahebourg
# Processing Record 42 of Set 6 | puerto escondido
# Processing Record 43 of Set 6 | pilar
# Processing Record 44 of Set 6 | moranbah
# Processing Record 45 of Set 6 | omsukchan
# Processing Record 46 of Set 6 | constitucion
# Processing Record 47 of Set 6 | ballina
# Processing Record 48 of Set 6 | panjab
# Processing Record 49 of Set 6 | coihaique
# Processing Record 50 of Set 6 | savalou
# Processing Record 1 of Set 7 | celestun
# Processing Record 2 of Set 7 | chuy
# Processing Record 3 of Set 7 | arraial do cabo
# Processing Record 4 of Set 7 | barraute
# Processing Record 5 of Set 7 | shubarshi
# Processing Record 6 of Set 7 | ozernovskiy
# Processing Record 7 of Set 7 | bosanska dubica
# Processing Record 8 of Set 7 | lao cai
# Processing Record 9 of Set 7 | sayyan
# Processing Record 10 of Set 7 | ampanihy
# Processing Record 11 of Set 7 | lydenburg
# Processing Record 12 of Set 7 | ust-nera
# Processing Record 13 of Set 7 | atambua
# Processing Record 14 of Set 7 | saint-joseph
# Processing Record 15 of Set 7 | tautira
# Processing Record 16 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 7 | camargo
# Processing Record 18 of Set 7 | tirumullaivasal
# Processing Record 19 of Set 7 | kearney
# Processing Record 20 of Set 7 | olinda
# Processing Record 21 of Set 7 | talcahuano
# Processing Record 22 of Set 7 | ternova
# Processing Record 23 of Set 7 | ilulissat
# Processing Record 24 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 7 | hay river
# Processing Record 26 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 7 | san patricio
# Processing Record 28 of Set 7 | doctor arroyo
# Processing Record 29 of Set 7 | niquero
# Processing Record 30 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 7 | saint-georges
# Processing Record 32 of Set 7 | valdosta
# Processing Record 33 of Set 7 | finschhafen
# Processing Record 34 of Set 7 | tiarei
# Processing Record 35 of Set 7 | zhigansk
# Processing Record 36 of Set 7 | iqaluit
# Processing Record 37 of Set 7 | malindi
# Processing Record 38 of Set 7 | umm kaddadah
# Processing Record 39 of Set 7 | warri
# Processing Record 40 of Set 7 | touros
# Processing Record 41 of Set 7 | khudumelapye
# Processing Record 42 of Set 7 | saint-francois
# Processing Record 43 of Set 7 | tual
# Processing Record 44 of Set 7 | kosh-agach
# Processing Record 45 of Set 7 | oktyabrskiy
# Processing Record 46 of Set 7 | moron
# Processing Record 47 of Set 7 | yelizovo
# Processing Record 48 of Set 7 | tari
# Processing Record 49 of Set 7 | aleksandrov gay
# Processing Record 50 of Set 7 | kizema
# Processing Record 1 of Set 8 | marzuq
# Processing Record 2 of Set 8 | okhotsk
# Processing Record 3 of Set 8 | rocha
# Processing Record 4 of Set 8 | richards bay
# Processing Record 5 of Set 8 | san pedro de ycuamandiyu
# Processing Record 6 of Set 8 | nshamba
# Processing Record 7 of Set 8 | srednekolymsk
# Processing Record 8 of Set 8 | jinchang
# Processing Record 9 of Set 8 | isla vista
# Processing Record 10 of Set 8 | salekhard
# Processing Record 11 of Set 8 | jamsa
# Processing Record 12 of Set 8 | sindand
# City not found. Skipping...
# Processing Record 13 of Set 8 | sioux lookout
# Processing Record 14 of Set 8 | yulara
# Processing Record 15 of Set 8 | toowoomba
# Processing Record 16 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 8 | wangqing
# Processing Record 18 of Set 8 | portland
# Processing Record 19 of Set 8 | husavik
# Processing Record 20 of Set 8 | aswan
# Processing Record 21 of Set 8 | rosa zarate
# Processing Record 22 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 8 | askarovo
# Processing Record 24 of Set 8 | beringovskiy
# Processing Record 25 of Set 8 | zhangjiakou
# Processing Record 26 of Set 8 | manaring
# Processing Record 27 of Set 8 | oussouye
# Processing Record 28 of Set 8 | tessalit
# Processing Record 29 of Set 8 | castro
# Processing Record 30 of Set 8 | haldwani
# Processing Record 31 of Set 8 | kitgum
# Processing Record 32 of Set 8 | henties bay
# Processing Record 33 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 8 | angoche
# Processing Record 35 of Set 8 | houma
# Processing Record 36 of Set 8 | mayumba
# Processing Record 37 of Set 8 | dunedin
# Processing Record 38 of Set 8 | kushima
# Processing Record 39 of Set 8 | alofi
# Processing Record 40 of Set 8 | vidim
# Processing Record 41 of Set 8 | bloomfield
# Processing Record 42 of Set 8 | koumac
# Processing Record 43 of Set 8 | harper
# Processing Record 44 of Set 8 | navrongo
# Processing Record 45 of Set 8 | mareeba
# Processing Record 46 of Set 8 | ransang
# Processing Record 47 of Set 8 | udachnyy
# Processing Record 48 of Set 8 | isla mujeres
# Processing Record 49 of Set 8 | itoman
# Processing Record 50 of Set 8 | leningradskiy
# Processing Record 1 of Set 9 | grand-bourg
# Processing Record 2 of Set 9 | okha
# Processing Record 3 of Set 9 | muros
# Processing Record 4 of Set 9 | cayenne
# Processing Record 5 of Set 9 | mehamn
# Processing Record 6 of Set 9 | padang
# Processing Record 7 of Set 9 | lixourion
# Processing Record 8 of Set 9 | maribo
# Processing Record 9 of Set 9 | punta alta
# Processing Record 10 of Set 9 | davila
# Processing Record 11 of Set 9 | dudinka
# Processing Record 12 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 9 | waipawa
# Processing Record 14 of Set 9 | steamboat springs
# Processing Record 15 of Set 9 | mumford
# Processing Record 16 of Set 9 | atescatempa
# Processing Record 17 of Set 9 | south venice
# Processing Record 18 of Set 9 | lorengau
# Processing Record 19 of Set 9 | sur
# Processing Record 20 of Set 9 | balkanabat
# Processing Record 21 of Set 9 | port blair
# Processing Record 22 of Set 9 | riverton
# Processing Record 23 of Set 9 | vallenar
# Processing Record 24 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 9 | sao jose da coroa grande
# Processing Record 26 of Set 9 | san luis
# Processing Record 27 of Set 9 | port pirie
# Processing Record 28 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 9 | brekstad
# Processing Record 30 of Set 9 | russell
# Processing Record 31 of Set 9 | souris
# Processing Record 32 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 9 | laguna
# Processing Record 34 of Set 9 | magadan
# Processing Record 35 of Set 9 | namtsy
# Processing Record 36 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 37 of Set 9 | ancud
# Processing Record 38 of Set 9 | praia da vitoria
# Processing Record 39 of Set 9 | koboldo
# City not found. Skipping...
# Processing Record 40 of Set 9 | la palma
# Processing Record 41 of Set 9 | san lorenzo
# Processing Record 42 of Set 9 | fort wellington
# Processing Record 43 of Set 9 | hofn
# Processing Record 44 of Set 9 | sembe
# Processing Record 45 of Set 9 | karaton
# Processing Record 46 of Set 9 | soyo
# Processing Record 47 of Set 9 | keti bandar
# Processing Record 48 of Set 9 | carutapera
# Processing Record 49 of Set 9 | olafsvik
# Processing Record 50 of Set 9 | gadung
# Processing Record 1 of Set 10 | baoqing
# Processing Record 2 of Set 10 | ambon
# Processing Record 3 of Set 10 | port macquarie
# Processing Record 4 of Set 10 | taltal
# Processing Record 5 of Set 10 | noumea
# Processing Record 6 of Set 10 | ambilobe
# Processing Record 7 of Set 10 | kotlas
# Processing Record 8 of Set 10 | imeni poliny osipenko
# Processing Record 9 of Set 10 | lodeynoye pole
# Processing Record 10 of Set 10 | lincoln
# Processing Record 11 of Set 10 | gari
# Processing Record 12 of Set 10 | alvaraes
# Processing Record 13 of Set 10 | polson
# Processing Record 14 of Set 10 | talnakh
# Processing Record 15 of Set 10 | cabo rojo
# Processing Record 16 of Set 10 | san alberto
# Processing Record 17 of Set 10 | mumbwa
# Processing Record 18 of Set 10 | tuatapere
# Processing Record 19 of Set 10 | palmer
# Processing Record 20 of Set 10 | koutsouras
# Processing Record 21 of Set 10 | south lake tahoe
# Processing Record 22 of Set 10 | kirensk
# Processing Record 23 of Set 10 | changping
# Processing Record 24 of Set 10 | yagodnoye
# Processing Record 25 of Set 10 | kirakira
# Processing Record 26 of Set 10 | wahpeton
# Processing Record 27 of Set 10 | kavaratti
# Processing Record 28 of Set 10 | kidal
# Processing Record 29 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 10 | muriwai beach
# Processing Record 31 of Set 10 | bucerias
# Processing Record 32 of Set 10 | marawi
# Processing Record 33 of Set 10 | kangaatsiaq
# Processing Record 34 of Set 10 | knysna
# Processing Record 35 of Set 10 | charters towers
# Processing Record 36 of Set 10 | amuntai
# Processing Record 37 of Set 10 | clyde river
# Processing Record 38 of Set 10 | zakamensk
# Processing Record 39 of Set 10 | sharan
# Processing Record 40 of Set 10 | austin
# Processing Record 41 of Set 10 | faanui
# Processing Record 42 of Set 10 | zhezkazgan
# Processing Record 43 of Set 10 | komsomolskiy
# Processing Record 44 of Set 10 | ugoofaaru
# Processing Record 45 of Set 10 | balkhash
# Processing Record 46 of Set 10 | libreville
# Processing Record 47 of Set 10 | maragogi
# Processing Record 48 of Set 10 | ijero
# Processing Record 49 of Set 10 | mahon
# Processing Record 50 of Set 10 | bandarbeyla
# Processing Record 1 of Set 11 | awbari
# Processing Record 2 of Set 11 | ondangwa
# Processing Record 3 of Set 11 | lavrentiya
# Processing Record 4 of Set 11 | quang ngai
# Processing Record 5 of Set 11 | crixas
# Processing Record 6 of Set 11 | severobaykalsk
# Processing Record 7 of Set 11 | saint-pierre
# Processing Record 8 of Set 11 | san vicente
# Processing Record 9 of Set 11 | turtkul
# City not found. Skipping...
# Processing Record 10 of Set 11 | scottsbluff
# Processing Record 11 of Set 11 | sinjar
# Processing Record 12 of Set 11 | perth
# Processing Record 13 of Set 11 | ocampo
# Processing Record 14 of Set 11 | vardo
# Processing Record 15 of Set 11 | cartagena del chaira
# Processing Record 16 of Set 11 | tulun
# Processing Record 17 of Set 11 | puebloviejo
# Processing Record 18 of Set 11 | deputatskiy
# Processing Record 19 of Set 11 | mporokoso
# Processing Record 20 of Set 11 | haines junction
# Processing Record 21 of Set 11 | chorbog
# City not found. Skipping...
# Processing Record 22 of Set 11 | rincon
# Processing Record 23 of Set 11 | wagar
# Processing Record 24 of Set 11 | jacareacanga
# Processing Record 25 of Set 11 | whitianga
# Processing Record 26 of Set 11 | linxia
# Processing Record 27 of Set 11 | dubbo
# Processing Record 28 of Set 11 | buon me thuot
# City not found. Skipping...
# Processing Record 29 of Set 11 | naze
# Processing Record 30 of Set 11 | griffith
# Processing Record 31 of Set 11 | mildura
# Processing Record 32 of Set 11 | iguatu
# Processing Record 33 of Set 11 | enkhuizen
# Processing Record 34 of Set 11 | sola
# Processing Record 35 of Set 11 | mersing
# Processing Record 36 of Set 11 | robore
# Processing Record 37 of Set 11 | chokwe
# Processing Record 38 of Set 11 | sorland
# Processing Record 39 of Set 11 | choix
# Processing Record 40 of Set 11 | pirot
# Processing Record 41 of Set 11 | ocara
# Processing Record 42 of Set 11 | ulladulla
# Processing Record 43 of Set 11 | el alto
# Processing Record 44 of Set 11 | arlit
# Processing Record 45 of Set 11 | garden city
# Processing Record 46 of Set 11 | delmas
# Processing Record 47 of Set 11 | kattivakkam
# Processing Record 48 of Set 11 | fare
# Processing Record 49 of Set 11 | camacha
# Processing Record 50 of Set 11 | coahuayana
# Processing Record 1 of Set 12 | cururupu
# Processing Record 2 of Set 12 | waingapu
# Processing Record 3 of Set 12 | forssa
# Processing Record 4 of Set 12 | mao
# Processing Record 5 of Set 12 | road town
# Processing Record 6 of Set 12 | avera
# Processing Record 7 of Set 12 | guilford
# Processing Record 8 of Set 12 | anadyr
# Processing Record 9 of Set 12 | diamantino
# Processing Record 10 of Set 12 | roald
# Processing Record 11 of Set 12 | leh
# Processing Record 12 of Set 12 | rio gallegos
# Processing Record 13 of Set 12 | farah
# Processing Record 14 of Set 12 | homer
# Processing Record 15 of Set 12 | chamrajnagar
# Processing Record 16 of Set 12 | micheweni
# Processing Record 17 of Set 12 | yumen
# Processing Record 18 of Set 12 | ranong
# Processing Record 19 of Set 12 | perafita
# Processing Record 20 of Set 12 | ipameri
# Processing Record 21 of Set 12 | jahrom
# City not found. Skipping...
# Processing Record 22 of Set 12 | manama
# Processing Record 23 of Set 12 | puerto plata
# Processing Record 24 of Set 12 | borovskiy
# Processing Record 25 of Set 12 | cherskiy
# Processing Record 26 of Set 12 | pacific grove
# Processing Record 27 of Set 12 | te anau
# Processing Record 28 of Set 12 | waw
# Processing Record 29 of Set 12 | omurtag
# Processing Record 30 of Set 12 | nokaneng
# Processing Record 31 of Set 12 | coreau
# Processing Record 32 of Set 12 | orumiyeh
# Processing Record 33 of Set 12 | kapit
# Processing Record 34 of Set 12 | fairbanks
# Processing Record 35 of Set 12 | bud
# Processing Record 36 of Set 12 | tambul
# City not found. Skipping...
# Processing Record 37 of Set 12 | chipinge
# Processing Record 38 of Set 12 | vyazemskiy
# Processing Record 39 of Set 12 | nouakchott
# Processing Record 40 of Set 12 | wufeng
# Processing Record 41 of Set 12 | tallahassee
# Processing Record 42 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 12 | gizo
# Processing Record 44 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 12 | krosno odrzanskie
# Processing Record 46 of Set 12 | chivay
# Processing Record 47 of Set 12 | pietersburg
# Processing Record 48 of Set 12 | inhuma
# Processing Record 49 of Set 12 | midyat
# Processing Record 50 of Set 12 | tanout
# Processing Record 1 of Set 13 | baykit
# Processing Record 2 of Set 13 | ye
# City not found. Skipping...
# Processing Record 3 of Set 13 | lazaro cardenas
# Processing Record 4 of Set 13 | thalgau
# Processing Record 5 of Set 13 | chiredzi
# Processing Record 6 of Set 13 | seymchan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Faya  18.3851   42.4509     66.31        61          21
# 1         Pishva  35.3080   51.7267     76.64        31           0
# 2         Luanda  -8.8368   13.2343     75.20        83          20
# 3          Ileza  61.0533   43.9002     46.04        98         100
# 4  Cockburn Town  21.4612  -71.1419     83.55        72          30
# 5        Ushuaia -54.8000  -68.3000     46.06        46           0
# 6    Mikhaylovka  50.0600   43.2379     70.79        51         100
# 7      Saskylakh  71.9167  114.0833     25.07        94         100
# 8    Derzhavinsk  51.1000   66.3167     37.92        35           0
# 9        Rikitea -23.1203 -134.9692     73.92        69          49
#
#    Wind Speed Country                 Date
# 0        4.29      SA  2022-10-02 17:58:00
# 1        6.98      IR  2022-10-02 17:58:01
# 2        6.91      AO  2022-10-02 17:58:01
# 3        4.45      RU  2022-10-02 17:58:02
# 4        5.91      TC  2022-10-02 17:58:02
# 5        5.75      AR  2022-10-02 17:58:02
# 6       19.26      RU  2022-10-02 17:58:03
# 7       14.27      RU  2022-10-02 17:58:04
# 8        8.23      KZ  2022-10-02 17:58:04
# 9        6.53      PF  2022-10-02 17:58:04

# %%
# Rearrange column order
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0           Faya      SA  2022-10-02 17:58:00  18.3851   42.4509     66.31
# 1         Pishva      IR  2022-10-02 17:58:01  35.3080   51.7267     76.64
# 2         Luanda      AO  2022-10-02 17:58:01  -8.8368   13.2343     75.20
# 3          Ileza      RU  2022-10-02 17:58:02  61.0533   43.9002     46.04
# 4  Cockburn Town      TC  2022-10-02 17:58:02  21.4612  -71.1419     83.55
# 5        Ushuaia      AR  2022-10-02 17:58:02 -54.8000  -68.3000     46.06
# 6    Mikhaylovka      RU  2022-10-02 17:58:03  50.0600   43.2379     70.79
# 7      Saskylakh      RU  2022-10-02 17:58:04  71.9167  114.0833     25.07
# 8    Derzhavinsk      KZ  2022-10-02 17:58:04  51.1000   66.3167     37.92
# 9        Rikitea      PF  2022-10-02 17:58:04 -23.1203 -134.9692     73.92
#
#    Humidity  Cloudiness  Wind Speed
# 0        61          21        4.29
# 1        31           0        6.98
# 2        83          20        6.91
# 3        98         100        4.45
# 4        72          30        5.91
# 5        46           0        5.75
# 6        51         100       19.26
# 7        94         100       14.27
# 8        35           0        8.23
# 9        69          49        6.53

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

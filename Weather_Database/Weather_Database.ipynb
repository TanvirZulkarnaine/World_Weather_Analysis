# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 784

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | uray
# Processing Record 2 of Set 1 | vanimo
# Processing Record 3 of Set 1 | caravelas
# Processing Record 4 of Set 1 | loreto
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | saskylakh
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | zhezkazgan
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | broome
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | cherskiy
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | tingo maria
# Processing Record 15 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | hofn
# Processing Record 18 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | sur
# Processing Record 21 of Set 1 | marrakesh
# Processing Record 22 of Set 1 | sydney
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | kashi
# Processing Record 26 of Set 1 | yakeshi
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | fort-shevchenko
# Processing Record 29 of Set 1 | chuy
# Processing Record 30 of Set 1 | sunland park
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | brownsville
# Processing Record 33 of Set 1 | port hedland
# Processing Record 34 of Set 1 | gaozhou
# Processing Record 35 of Set 1 | nanortalik
# Processing Record 36 of Set 1 | baraboo
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | cerkezkoy
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | vila franca do campo
# Processing Record 43 of Set 1 | orebro
# Processing Record 44 of Set 1 | hasaki
# Processing Record 45 of Set 1 | adrar
# Processing Record 46 of Set 1 | tura
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | guerrero negro
# Processing Record 50 of Set 1 | bathsheba
# Processing Record 1 of Set 2 | henties bay
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | bahile
# Processing Record 5 of Set 2 | dhidhdhoo
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | luanda
# Processing Record 9 of Set 2 | salym
# Processing Record 10 of Set 2 | lavrentiya
# Processing Record 11 of Set 2 | caucaia
# Processing Record 12 of Set 2 | north bend
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | barranca
# Processing Record 15 of Set 2 | nuuk
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | marfino
# Processing Record 18 of Set 2 | phun phin
# City not found. Skipping...
# Processing Record 19 of Set 2 | nishihara
# Processing Record 20 of Set 2 | ciudad arce
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | lebu
# Processing Record 23 of Set 2 | siilinjarvi
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 2 | palana
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | vestmannaeyjar
# Processing Record 29 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 2 | rockland
# Processing Record 31 of Set 2 | ancud
# Processing Record 32 of Set 2 | geraldton
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | takoradi
# Processing Record 35 of Set 2 | hobyo
# Processing Record 36 of Set 2 | albany
# Processing Record 37 of Set 2 | cidreira
# Processing Record 38 of Set 2 | kapoeta
# Processing Record 39 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | goleniow
# Processing Record 41 of Set 2 | provideniya
# Processing Record 42 of Set 2 | pineville
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | yerkoy
# Processing Record 45 of Set 2 | acapulco
# Processing Record 46 of Set 2 | san cristobal
# Processing Record 47 of Set 2 | agnibilekrou
# Processing Record 48 of Set 2 | puerto escondido
# Processing Record 49 of Set 2 | saint anthony
# Processing Record 50 of Set 2 | yenagoa
# Processing Record 1 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 2 of Set 3 | sept-iles
# Processing Record 3 of Set 3 | ilulissat
# Processing Record 4 of Set 3 | santiago del estero
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 7 of Set 3 | batagay
# Processing Record 8 of Set 3 | iquitos
# Processing Record 9 of Set 3 | butaritari
# Processing Record 10 of Set 3 | melton mowbray
# Processing Record 11 of Set 3 | naze
# Processing Record 12 of Set 3 | iquique
# Processing Record 13 of Set 3 | darhan
# Processing Record 14 of Set 3 | changtu
# Processing Record 15 of Set 3 | castro
# Processing Record 16 of Set 3 | sorland
# Processing Record 17 of Set 3 | salinopolis
# Processing Record 18 of Set 3 | coahuayana
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | vardo
# Processing Record 21 of Set 3 | ilo
# Processing Record 22 of Set 3 | pangnirtung
# Processing Record 23 of Set 3 | hobart
# Processing Record 24 of Set 3 | caibarien
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | norman wells
# Processing Record 28 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 3 | saint-philippe
# Processing Record 30 of Set 3 | maridi
# Processing Record 31 of Set 3 | port hardy
# Processing Record 32 of Set 3 | margate
# Processing Record 33 of Set 3 | belmonte
# Processing Record 34 of Set 3 | paracuru
# Processing Record 35 of Set 3 | fort nelson
# Processing Record 36 of Set 3 | carnarvon
# Processing Record 37 of Set 3 | ust-kulom
# Processing Record 38 of Set 3 | chicama
# Processing Record 39 of Set 3 | tayga
# Processing Record 40 of Set 3 | hamilton
# Processing Record 41 of Set 3 | roald
# Processing Record 42 of Set 3 | borisoglebskiy
# Processing Record 43 of Set 3 | makakilo city
# Processing Record 44 of Set 3 | grootfontein
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | radford
# Processing Record 47 of Set 3 | teguldet
# Processing Record 48 of Set 3 | belyy yar
# Processing Record 49 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 4 | chapais
# Processing Record 2 of Set 4 | wilhelmshaven
# Processing Record 3 of Set 4 | mahebourg
# Processing Record 4 of Set 4 | cody
# Processing Record 5 of Set 4 | port blair
# Processing Record 6 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 4 | krutikha
# Processing Record 8 of Set 4 | kahului
# Processing Record 9 of Set 4 | beringovskiy
# Processing Record 10 of Set 4 | santo antonio do ica
# Processing Record 11 of Set 4 | asau
# Processing Record 12 of Set 4 | pacific grove
# Processing Record 13 of Set 4 | cockburn town
# Processing Record 14 of Set 4 | mar del plata
# Processing Record 15 of Set 4 | tecoanapa
# Processing Record 16 of Set 4 | muros
# Processing Record 17 of Set 4 | kununurra
# Processing Record 18 of Set 4 | sinnamary
# Processing Record 19 of Set 4 | hualmay
# Processing Record 20 of Set 4 | byron bay
# Processing Record 21 of Set 4 | prado
# Processing Record 22 of Set 4 | fortuna
# Processing Record 23 of Set 4 | malartic
# Processing Record 24 of Set 4 | saint-augustin
# Processing Record 25 of Set 4 | betki
# City not found. Skipping...
# Processing Record 26 of Set 4 | lalomanu
# City not found. Skipping...
# Processing Record 27 of Set 4 | port elizabeth
# Processing Record 28 of Set 4 | coquimbo
# Processing Record 29 of Set 4 | gorban
# Processing Record 30 of Set 4 | berlevag
# Processing Record 31 of Set 4 | liku
# Processing Record 32 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 4 | thompson
# Processing Record 34 of Set 4 | longyearbyen
# Processing Record 35 of Set 4 | omboue
# Processing Record 36 of Set 4 | srednekolymsk
# Processing Record 37 of Set 4 | presidencia roque saenz pena
# Processing Record 38 of Set 4 | gayny
# Processing Record 39 of Set 4 | poya
# Processing Record 40 of Set 4 | quatre cocos
# Processing Record 41 of Set 4 | lagoa
# Processing Record 42 of Set 4 | dzaoudzi
# Processing Record 43 of Set 4 | nadym
# Processing Record 44 of Set 4 | san patricio
# Processing Record 45 of Set 4 | mount gambier
# Processing Record 46 of Set 4 | pangkalanbuun
# Processing Record 47 of Set 4 | la palma
# Processing Record 48 of Set 4 | manaure
# Processing Record 49 of Set 4 | qaanaaq
# Processing Record 50 of Set 4 | saint-pierre
# Processing Record 1 of Set 5 | dakar
# Processing Record 2 of Set 5 | port-gentil
# Processing Record 3 of Set 5 | halifax
# Processing Record 4 of Set 5 | marawi
# Processing Record 5 of Set 5 | robe
# Processing Record 6 of Set 5 | ligayan
# Processing Record 7 of Set 5 | alakurtti
# Processing Record 8 of Set 5 | manggar
# Processing Record 9 of Set 5 | ixtapa
# Processing Record 10 of Set 5 | antofagasta
# Processing Record 11 of Set 5 | porto recanati
# Processing Record 12 of Set 5 | laguna
# Processing Record 13 of Set 5 | souillac
# Processing Record 14 of Set 5 | praxedis guerrero
# Processing Record 15 of Set 5 | yulara
# Processing Record 16 of Set 5 | san lorenzo
# Processing Record 17 of Set 5 | ipanguacu
# Processing Record 18 of Set 5 | bongor
# Processing Record 19 of Set 5 | afonso bezerra
# Processing Record 20 of Set 5 | chillicothe
# Processing Record 21 of Set 5 | gusau
# Processing Record 22 of Set 5 | codrington
# Processing Record 23 of Set 5 | cap malheureux
# Processing Record 24 of Set 5 | lieksa
# Processing Record 25 of Set 5 | helong
# Processing Record 26 of Set 5 | luderitz
# Processing Record 27 of Set 5 | sanary-sur-mer
# Processing Record 28 of Set 5 | jacareacanga
# Processing Record 29 of Set 5 | barzas
# Processing Record 30 of Set 5 | constitucion
# Processing Record 31 of Set 5 | sao filipe
# Processing Record 32 of Set 5 | strezhevoy
# Processing Record 33 of Set 5 | caribou
# Processing Record 34 of Set 5 | goderich
# Processing Record 35 of Set 5 | casper
# Processing Record 36 of Set 5 | harper
# Processing Record 37 of Set 5 | kichmengskiy gorodok
# Processing Record 38 of Set 5 | faanui
# Processing Record 39 of Set 5 | havoysund
# Processing Record 40 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 5 | kodaikanal
# Processing Record 42 of Set 5 | aksarka
# Processing Record 43 of Set 5 | saldanha
# Processing Record 44 of Set 5 | torrington
# Processing Record 45 of Set 5 | finschhafen
# Processing Record 46 of Set 5 | nome
# Processing Record 47 of Set 5 | calama
# Processing Record 48 of Set 5 | tautira
# Processing Record 49 of Set 5 | vila velha
# Processing Record 50 of Set 5 | mundybash
# Processing Record 1 of Set 6 | portland
# Processing Record 2 of Set 6 | storsteinnes
# Processing Record 3 of Set 6 | ca mau
# Processing Record 4 of Set 6 | lima
# Processing Record 5 of Set 6 | kavieng
# Processing Record 6 of Set 6 | soledade
# Processing Record 7 of Set 6 | xiangfan
# Processing Record 8 of Set 6 | hongjiang
# Processing Record 9 of Set 6 | fairbanks
# Processing Record 10 of Set 6 | vostok
# Processing Record 11 of Set 6 | oliveira dos brejinhos
# Processing Record 12 of Set 6 | kavaratti
# Processing Record 13 of Set 6 | kapustin yar
# Processing Record 14 of Set 6 | sao jose da coroa grande
# Processing Record 15 of Set 6 | totolapan
# Processing Record 16 of Set 6 | cuamba
# Processing Record 17 of Set 6 | dongsheng
# Processing Record 18 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 19 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 6 | kautokeino
# Processing Record 21 of Set 6 | mocuba
# Processing Record 22 of Set 6 | barcelona
# Processing Record 23 of Set 6 | colares
# Processing Record 24 of Set 6 | qaqortoq
# Processing Record 25 of Set 6 | torbay
# Processing Record 26 of Set 6 | kashan
# Processing Record 27 of Set 6 | mehamn
# Processing Record 28 of Set 6 | ardabil
# Processing Record 29 of Set 6 | kilmez
# City not found. Skipping...
# Processing Record 30 of Set 6 | liwale
# Processing Record 31 of Set 6 | ust-kuyga
# Processing Record 32 of Set 6 | lagos
# Processing Record 33 of Set 6 | kayerkan
# Processing Record 34 of Set 6 | alice springs
# Processing Record 35 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 6 | oreanda
# City not found. Skipping...
# Processing Record 37 of Set 6 | poronaysk
# Processing Record 38 of Set 6 | matara
# Processing Record 39 of Set 6 | buraydah
# Processing Record 40 of Set 6 | mountain home
# Processing Record 41 of Set 6 | nantucket
# Processing Record 42 of Set 6 | concarneau
# Processing Record 43 of Set 6 | georgetown
# Processing Record 44 of Set 6 | tuktoyaktuk
# Processing Record 45 of Set 6 | puerto leguizamo
# Processing Record 46 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 6 | steinbach
# Processing Record 49 of Set 6 | ambilobe
# Processing Record 50 of Set 6 | gamba
# Processing Record 1 of Set 7 | te anau
# Processing Record 2 of Set 7 | french harbor
# Processing Record 3 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 7 | angoche
# Processing Record 5 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | sharjah
# Processing Record 7 of Set 7 | grafton
# Processing Record 8 of Set 7 | sandy bay
# Processing Record 9 of Set 7 | san javier
# Processing Record 10 of Set 7 | goya
# Processing Record 11 of Set 7 | mezen
# Processing Record 12 of Set 7 | kermanshah
# Processing Record 13 of Set 7 | bethel
# Processing Record 14 of Set 7 | cabo san lucas
# Processing Record 15 of Set 7 | hwange
# Processing Record 16 of Set 7 | nelson bay
# Processing Record 17 of Set 7 | wiarton
# Processing Record 18 of Set 7 | vao
# Processing Record 19 of Set 7 | bengkulu
# Processing Record 20 of Set 7 | greifswald
# Processing Record 21 of Set 7 | vila
# Processing Record 22 of Set 7 | placido de castro
# Processing Record 23 of Set 7 | rio gallegos
# Processing Record 24 of Set 7 | beverley
# Processing Record 25 of Set 7 | sabang
# Processing Record 26 of Set 7 | san jose
# Processing Record 27 of Set 7 | manzil tamim
# City not found. Skipping...
# Processing Record 28 of Set 7 | maragogi
# Processing Record 29 of Set 7 | nyurba
# Processing Record 30 of Set 7 | nikolskoye
# Processing Record 31 of Set 7 | hvide sande
# Processing Record 32 of Set 7 | cortez
# Processing Record 33 of Set 7 | roswell
# Processing Record 34 of Set 7 | ribeira grande
# Processing Record 35 of Set 7 | keuruu
# Processing Record 36 of Set 7 | mapiri
# Processing Record 37 of Set 7 | richards bay
# Processing Record 38 of Set 7 | olafsvik
# Processing Record 39 of Set 7 | taos
# Processing Record 40 of Set 7 | kaitangata
# Processing Record 41 of Set 7 | belorechensk
# Processing Record 42 of Set 7 | mackenzie
# Processing Record 43 of Set 7 | luena
# Processing Record 44 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 45 of Set 7 | zadar
# Processing Record 46 of Set 7 | almaznyy
# Processing Record 47 of Set 7 | port macquarie
# Processing Record 48 of Set 7 | sakhon nakhon
# Processing Record 49 of Set 7 | howard springs
# Processing Record 50 of Set 7 | varkaus
# Processing Record 1 of Set 8 | luebo
# Processing Record 2 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 8 | kilindoni
# Processing Record 4 of Set 8 | kenai
# Processing Record 5 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 8 | kidal
# Processing Record 7 of Set 8 | verkhnyaya inta
# Processing Record 8 of Set 8 | sile
# Processing Record 9 of Set 8 | necochea
# Processing Record 10 of Set 8 | sioux lookout
# Processing Record 11 of Set 8 | shingu
# Processing Record 12 of Set 8 | road town
# Processing Record 13 of Set 8 | karratha
# Processing Record 14 of Set 8 | keflavik
# Processing Record 15 of Set 8 | prince albert
# Processing Record 16 of Set 8 | hirara
# Processing Record 17 of Set 8 | la ciotat
# Processing Record 18 of Set 8 | pevek
# Processing Record 19 of Set 8 | labytnangi
# Processing Record 20 of Set 8 | plyussa
# Processing Record 21 of Set 8 | tuatapere
# Processing Record 22 of Set 8 | santa cruz
# Processing Record 23 of Set 8 | bubaque
# Processing Record 24 of Set 8 | matagami
# Processing Record 25 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 8 | chokurdakh
# Processing Record 27 of Set 8 | taseyevo
# Processing Record 28 of Set 8 | zanjan
# Processing Record 29 of Set 8 | pangoa
# Processing Record 30 of Set 8 | lemesos
# City not found. Skipping...
# Processing Record 31 of Set 8 | tamworth
# Processing Record 32 of Set 8 | kuryk
# Processing Record 33 of Set 8 | hvolsvollur
# Processing Record 34 of Set 8 | brae
# Processing Record 35 of Set 8 | bambous virieux
# Processing Record 36 of Set 8 | campeche
# Processing Record 37 of Set 8 | gillette
# Processing Record 38 of Set 8 | chauk
# Processing Record 39 of Set 8 | banjar
# Processing Record 40 of Set 8 | leningradskiy
# Processing Record 41 of Set 8 | sao joao da barra
# Processing Record 42 of Set 8 | tocopilla
# Processing Record 43 of Set 8 | tilichiki
# Processing Record 44 of Set 8 | airai
# Processing Record 45 of Set 8 | palamos
# Processing Record 46 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 47 of Set 8 | katsuura
# Processing Record 48 of Set 8 | ishigaki
# Processing Record 49 of Set 8 | am timan
# Processing Record 50 of Set 8 | platonovka
# Processing Record 1 of Set 9 | brokopondo
# Processing Record 2 of Set 9 | boyolangu
# Processing Record 3 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 9 | maniitsoq
# Processing Record 5 of Set 9 | nabire
# Processing Record 6 of Set 9 | paamiut
# Processing Record 7 of Set 9 | cacapava do sul
# Processing Record 8 of Set 9 | wajir
# Processing Record 9 of Set 9 | san-pedro
# Processing Record 10 of Set 9 | yamada
# Processing Record 11 of Set 9 | tottori
# Processing Record 12 of Set 9 | tadine
# Processing Record 13 of Set 9 | anori
# Processing Record 14 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 9 | ternate
# Processing Record 16 of Set 9 | bharatpur
# Processing Record 17 of Set 9 | moss point
# Processing Record 18 of Set 9 | mineros
# Processing Record 19 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 9 | lahij
# Processing Record 21 of Set 9 | progreso
# Processing Record 22 of Set 9 | porangatu
# Processing Record 23 of Set 9 | buala
# Processing Record 24 of Set 9 | hebertville
# City not found. Skipping...
# Processing Record 25 of Set 9 | mastic beach
# Processing Record 26 of Set 9 | lasa
# Processing Record 27 of Set 9 | wentzville
# Processing Record 28 of Set 9 | ihosy
# Processing Record 29 of Set 9 | khudaganj
# Processing Record 30 of Set 9 | komsomolskiy
# Processing Record 31 of Set 9 | kudahuvadhoo
# Processing Record 32 of Set 9 | poum
# Processing Record 33 of Set 9 | coos bay
# Processing Record 34 of Set 9 | unity
# Processing Record 35 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 9 | san juan
# Processing Record 37 of Set 9 | mbulu
# Processing Record 38 of Set 9 | kulzeb
# City not found. Skipping...
# Processing Record 39 of Set 9 | el triunfo
# Processing Record 40 of Set 9 | marzuq
# Processing Record 41 of Set 9 | haslett
# Processing Record 42 of Set 9 | deniliquin
# Processing Record 43 of Set 9 | tulum
# Processing Record 44 of Set 9 | dingle
# Processing Record 45 of Set 9 | syracuse
# Processing Record 46 of Set 9 | surt
# Processing Record 47 of Set 9 | wuwei
# Processing Record 48 of Set 9 | mesyagutovo
# Processing Record 49 of Set 9 | jiwani
# Processing Record 50 of Set 9 | alofi
# Processing Record 1 of Set 10 | severo-kurilsk
# Processing Record 2 of Set 10 | aransas pass
# Processing Record 3 of Set 10 | namibe
# Processing Record 4 of Set 10 | bilibino
# Processing Record 5 of Set 10 | rawson
# Processing Record 6 of Set 10 | emporia
# Processing Record 7 of Set 10 | lompoc
# Processing Record 8 of Set 10 | vrangel
# Processing Record 9 of Set 10 | arlit
# Processing Record 10 of Set 10 | qurayyat
# Processing Record 11 of Set 10 | lorengau
# Processing Record 12 of Set 10 | yarada
# Processing Record 13 of Set 10 | hermiston
# Processing Record 14 of Set 10 | coihaique
# Processing Record 15 of Set 10 | santa marta
# Processing Record 16 of Set 10 | garissa
# Processing Record 17 of Set 10 | encantado
# Processing Record 18 of Set 10 | newport
# Processing Record 19 of Set 10 | skjervoy
# Processing Record 20 of Set 10 | eureka
# Processing Record 21 of Set 10 | inhambane
# Processing Record 22 of Set 10 | abonnema
# Processing Record 23 of Set 10 | pitimbu
# Processing Record 24 of Set 10 | jamuria
# Processing Record 25 of Set 10 | ugoofaaru
# Processing Record 26 of Set 10 | bobrovka
# Processing Record 27 of Set 10 | marion
# Processing Record 28 of Set 10 | manitouwadge
# Processing Record 29 of Set 10 | kilemary
# Processing Record 30 of Set 10 | hof
# Processing Record 31 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 10 | mecca
# Processing Record 33 of Set 10 | ostrovnoy
# Processing Record 34 of Set 10 | itaguacu
# Processing Record 35 of Set 10 | tarakan
# Processing Record 36 of Set 10 | touros
# Processing Record 37 of Set 10 | ponta delgada
# Processing Record 38 of Set 10 | maraa
# Processing Record 39 of Set 10 | talnakh
# Processing Record 40 of Set 10 | hami
# Processing Record 41 of Set 10 | hambantota
# Processing Record 42 of Set 10 | eregli
# Processing Record 43 of Set 10 | alexandria
# Processing Record 44 of Set 10 | le mars
# Processing Record 45 of Set 10 | changji
# Processing Record 46 of Set 10 | solnechnyy
# Processing Record 47 of Set 10 | kresttsy
# Processing Record 48 of Set 10 | gympie
# Processing Record 49 of Set 10 | killybegs
# Processing Record 50 of Set 10 | birao
# Processing Record 1 of Set 11 | sovetskiy
# Processing Record 2 of Set 11 | amuntai
# Processing Record 3 of Set 11 | agirish
# Processing Record 4 of Set 11 | kitgum
# Processing Record 5 of Set 11 | gold coast
# Processing Record 6 of Set 11 | campos
# Processing Record 7 of Set 11 | chara
# Processing Record 8 of Set 11 | sitka
# Processing Record 9 of Set 11 | gbadolite
# Processing Record 10 of Set 11 | isabela
# Processing Record 11 of Set 11 | giyon
# Processing Record 12 of Set 11 | perth
# Processing Record 13 of Set 11 | rio grande
# Processing Record 14 of Set 11 | sibolga
# Processing Record 15 of Set 11 | macenta
# Processing Record 16 of Set 11 | esperance
# Processing Record 17 of Set 11 | toamasina
# Processing Record 18 of Set 11 | alyangula
# Processing Record 19 of Set 11 | umm lajj
# Processing Record 20 of Set 11 | nouadhibou
# Processing Record 21 of Set 11 | imbituba
# Processing Record 22 of Set 11 | flinders
# Processing Record 23 of Set 11 | albanel
# Processing Record 24 of Set 11 | comodoro rivadavia
# Processing Record 25 of Set 11 | port hueneme
# Processing Record 26 of Set 11 | roma
# Processing Record 27 of Set 11 | goteborg
# City not found. Skipping...
# Processing Record 28 of Set 11 | sredniy ikorets
# Processing Record 29 of Set 11 | manzil bu zalafah
# Processing Record 30 of Set 11 | pemangkat
# Processing Record 31 of Set 11 | evanston
# Processing Record 32 of Set 11 | santa rosalia
# Processing Record 33 of Set 11 | salalah
# Processing Record 34 of Set 11 | clyde river
# Processing Record 35 of Set 11 | klaksvik
# Processing Record 36 of Set 11 | daulatpur
# Processing Record 37 of Set 11 | valley city
# Processing Record 38 of Set 11 | kruisfontein
# Processing Record 39 of Set 11 | willmar
# Processing Record 40 of Set 11 | gigmoto
# Processing Record 41 of Set 11 | aklavik
# Processing Record 42 of Set 11 | ordzhonikidze
# Processing Record 43 of Set 11 | upington
# Processing Record 44 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 45 of Set 11 | gallup
# Processing Record 46 of Set 11 | januaria
# Processing Record 47 of Set 11 | tual
# Processing Record 48 of Set 11 | los llanos de aridane
# Processing Record 49 of Set 11 | pine bluff
# Processing Record 50 of Set 11 | sinjhoro
# Processing Record 1 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 2 of Set 12 | grindavik
# Processing Record 3 of Set 12 | meulaboh
# Processing Record 4 of Set 12 | bergama
# Processing Record 5 of Set 12 | rajbiraj
# Processing Record 6 of Set 12 | carauari
# Processing Record 7 of Set 12 | prince rupert
# Processing Record 8 of Set 12 | belaya gora
# Processing Record 9 of Set 12 | pontianak
# Processing Record 10 of Set 12 | awbari
# Processing Record 11 of Set 12 | kijang
# Processing Record 12 of Set 12 | saint-francois
# Processing Record 13 of Set 12 | valle del guamuez
# Processing Record 14 of Set 12 | xining
# Processing Record 15 of Set 12 | kenitra
# Processing Record 16 of Set 12 | khawhai
# Processing Record 17 of Set 12 | jijiga
# Processing Record 18 of Set 12 | mabay
# Processing Record 19 of Set 12 | anadyr
# Processing Record 20 of Set 12 | xuddur
# Processing Record 21 of Set 12 | sheopur
# Processing Record 22 of Set 12 | tiznit
# Processing Record 23 of Set 12 | sistranda
# Processing Record 24 of Set 12 | lensk
# Processing Record 25 of Set 12 | linxia
# Processing Record 26 of Set 12 | hay river
# Processing Record 27 of Set 12 | baruun-urt
# Processing Record 28 of Set 12 | mattawa
# Processing Record 29 of Set 12 | miraflores
# Processing Record 30 of Set 12 | baijiantan
# Processing Record 31 of Set 12 | gravdal
# Processing Record 32 of Set 12 | tupik
# Processing Record 33 of Set 12 | bardiyah
# Processing Record 34 of Set 12 | porbandar
# Processing Record 35 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 36 of Set 12 | lichtenburg
# Processing Record 37 of Set 12 | longhua
# Processing Record 38 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 39 of Set 12 | uvalde
# Processing Record 40 of Set 12 | sobolevo
# Processing Record 41 of Set 12 | pacifica
# Processing Record 42 of Set 12 | namatanai
# Processing Record 43 of Set 12 | avera
# Processing Record 44 of Set 12 | san vicente
# Processing Record 45 of Set 12 | mayahi
# Processing Record 46 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 12 | la ronge
# Processing Record 48 of Set 12 | teknaf
# Processing Record 49 of Set 12 | doha
# Processing Record 50 of Set 12 | qafsah
# City not found. Skipping...
# Processing Record 1 of Set 13 | muli
# Processing Record 2 of Set 13 | bama
# Processing Record 3 of Set 13 | kaeo
# Processing Record 4 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 13 | taonan
# Processing Record 6 of Set 13 | mount isa
# Processing Record 7 of Set 13 | bandarbeyla
# Processing Record 8 of Set 13 | port keats
# Processing Record 9 of Set 13 | onega
# Processing Record 10 of Set 13 | westport
# Processing Record 11 of Set 13 | socorro
# Processing Record 12 of Set 13 | minsk
# Processing Record 13 of Set 13 | kontagora
# Processing Record 14 of Set 13 | dwarka
# Processing Record 15 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 13 | aban
# Processing Record 17 of Set 13 | kutum
# Processing Record 18 of Set 13 | hanna
# Processing Record 19 of Set 13 | rocha
# Processing Record 20 of Set 13 | daliao
# Processing Record 21 of Set 13 | kolokani
# Processing Record 22 of Set 13 | san quintin
# Processing Record 23 of Set 13 | axim
# Processing Record 24 of Set 13 | xai-xai
# Processing Record 25 of Set 13 | kashmor
# Processing Record 26 of Set 13 | alihe
# Processing Record 27 of Set 13 | varhaug
# Processing Record 28 of Set 13 | san policarpo
# Processing Record 29 of Set 13 | sterling
# Processing Record 30 of Set 13 | khovu-aksy
# Processing Record 31 of Set 13 | kattivakkam
# Processing Record 32 of Set 13 | sechura
# Processing Record 33 of Set 13 | sobreira
# Processing Record 34 of Set 13 | udachnyy
# Processing Record 35 of Set 13 | trincomalee
# Processing Record 36 of Set 13 | saint george
# Processing Record 37 of Set 13 | khandyga
# Processing Record 38 of Set 13 | yerbogachen
# Processing Record 39 of Set 13 | sola
# Processing Record 40 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 13 | kedrovyy
# Processing Record 42 of Set 13 | port shepstone
# Processing Record 43 of Set 13 | mao
# Processing Record 44 of Set 13 | mirnyy
# Processing Record 45 of Set 13 | upata
# Processing Record 46 of Set 13 | camabatela
# Processing Record 47 of Set 13 | oktyabrskiy
# Processing Record 48 of Set 13 | bilma
# Processing Record 49 of Set 13 | blackwater
# Processing Record 50 of Set 13 | qorveh
# Processing Record 1 of Set 14 | dodge city
# Processing Record 2 of Set 14 | belm
# Processing Record 3 of Set 14 | porto novo
# Processing Record 4 of Set 14 | koumac
# Processing Record 5 of Set 14 | rodrigues alves
# Processing Record 6 of Set 14 | booue
# Processing Record 7 of Set 14 | akdepe
# Processing Record 8 of Set 14 | murgab
# Processing Record 9 of Set 14 | talca
# Processing Record 10 of Set 14 | timizart
# Processing Record 11 of Set 14 | okhotsk
# Processing Record 12 of Set 14 | gedo
# Processing Record 13 of Set 14 | oriximina
# Processing Record 14 of Set 14 | pringsewu
# Processing Record 15 of Set 14 | katherine
# Processing Record 16 of Set 14 | san angelo
# Processing Record 17 of Set 14 | aksarayskiy
# Processing Record 18 of Set 14 | moose factory
# Processing Record 19 of Set 14 | algemesi
# Processing Record 20 of Set 14 | paraiso
# Processing Record 21 of Set 14 | ulladulla
# Processing Record 22 of Set 14 | lobito
# Processing Record 23 of Set 14 | balykshi
# Processing Record 24 of Set 14 | kalakamati
# Processing Record 25 of Set 14 | cam ranh
# Processing Record 26 of Set 14 | marsh harbour
# Processing Record 27 of Set 14 | sokolovo
# Processing Record 28 of Set 14 | lewistown
# Processing Record 29 of Set 14 | pokrovskoye
# Processing Record 30 of Set 14 | jiaozhou
# Processing Record 31 of Set 14 | tetouan
# Processing Record 32 of Set 14 | menongue
# Processing Record 33 of Set 14 | vernon
# Processing Record 34 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 14 | garcia
# Processing Record 36 of Set 14 | kumluca
# Processing Record 37 of Set 14 | visoko
# Processing Record 38 of Set 14 | biak
# Processing Record 39 of Set 14 | wenatchee
# Processing Record 40 of Set 14 | lang son
# Processing Record 41 of Set 14 | ilhabela
# Processing Record 42 of Set 14 | viedma
# Processing Record 43 of Set 14 | gao
# Processing Record 44 of Set 14 | novoselytsya
# Processing Record 45 of Set 14 | tianpeng
# Processing Record 46 of Set 14 | ismailia
# Processing Record 47 of Set 14 | bonavista
# Processing Record 48 of Set 14 | tawnat
# City not found. Skipping...
# Processing Record 49 of Set 14 | cheyenne
# Processing Record 50 of Set 14 | del rio
# Processing Record 1 of Set 15 | manokwari
# Processing Record 2 of Set 15 | kainantu
# Processing Record 3 of Set 15 | ambon
# Processing Record 4 of Set 15 | puerto el triunfo
# Processing Record 5 of Set 15 | san mateo del mar
# Processing Record 6 of Set 15 | orshanka
# Processing Record 7 of Set 15 | gavle
# Processing Record 8 of Set 15 | tessalit
# Processing Record 9 of Set 15 | soyaltepec
# City not found. Skipping...
# Processing Record 10 of Set 15 | madera
# Processing Record 11 of Set 15 | jining
# Processing Record 12 of Set 15 | port hawkesbury
# Processing Record 13 of Set 15 | cherepovets
# Processing Record 14 of Set 15 | mookane
# Processing Record 15 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 15 | murmashi
# Processing Record 17 of Set 15 | pedernales
# Processing Record 18 of Set 15 | kamina
# Processing Record 19 of Set 15 | elko
# Processing Record 20 of Set 15 | rockingham
# Processing Record 21 of Set 15 | isangel
# Processing Record 22 of Set 15 | pilao arcado
# City not found. Skipping...
# Processing Record 23 of Set 15 | deputatskiy
# Processing Record 24 of Set 15 | paita
# Processing Record 25 of Set 15 | gat
# Processing Record 26 of Set 15 | channel-port aux basques
# Processing Record 27 of Set 15 | pisco
# Processing Record 28 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 29 of Set 15 | broken hill
# Processing Record 30 of Set 15 | buchanan
# Processing Record 31 of Set 15 | narsaq
# Processing Record 32 of Set 15 | el mante
# Processing Record 33 of Set 15 | general roca
# Processing Record 34 of Set 15 | aleksandrov gay
# Processing Record 35 of Set 15 | korem
# Processing Record 36 of Set 15 | denpasar
# Processing Record 37 of Set 15 | acarau
# Processing Record 38 of Set 15 | pemba
# Processing Record 39 of Set 15 | lincoln
# Processing Record 40 of Set 15 | murray bridge
# Processing Record 41 of Set 15 | oktyabrskoye
# Processing Record 42 of Set 15 | pascagoula
# Processing Record 43 of Set 15 | baiyin
# Processing Record 44 of Set 15 | roebourne
# Processing Record 45 of Set 15 | college
# Processing Record 46 of Set 15 | inta
# Processing Record 47 of Set 15 | atar
# Processing Record 48 of Set 15 | dutse
# Processing Record 49 of Set 15 | cayenne
# Processing Record 50 of Set 15 | verkhoyansk
# Processing Record 1 of Set 16 | marsa matruh
# Processing Record 2 of Set 16 | maasbracht
# Processing Record 3 of Set 16 | yicheng
# Processing Record 4 of Set 16 | teonthar
# Processing Record 5 of Set 16 | najran
# Processing Record 6 of Set 16 | santa cruz de tenerife
# Processing Record 7 of Set 16 | kloulklubed
# Processing Record 8 of Set 16 | limon
# Processing Record 9 of Set 16 | ocean city
# Processing Record 10 of Set 16 | nueva loja
# Processing Record 11 of Set 16 | itaparica
# Processing Record 12 of Set 16 | celestun
# Processing Record 13 of Set 16 | kuusamo
# Processing Record 14 of Set 16 | ensley
# Processing Record 15 of Set 16 | diapaga
# Processing Record 16 of Set 16 | caceres
# Processing Record 17 of Set 16 | grand gaube
# Processing Record 18 of Set 16 | anapskaya
# Processing Record 19 of Set 16 | de aar
# Processing Record 20 of Set 16 | san andres
# Processing Record 21 of Set 16 | cravo norte
# Processing Record 22 of Set 16 | yunjinghong
# City not found. Skipping...
# Processing Record 23 of Set 16 | labuhan
# Processing Record 24 of Set 16 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 16 | tawkar
# City not found. Skipping...
# Processing Record 26 of Set 16 | walvis bay
# Processing Record 27 of Set 16 | oum hadjer
# Processing Record 28 of Set 16 | ust-ishim
# Processing Record 29 of Set 16 | itarema
# Processing Record 30 of Set 16 | nurota
# Processing Record 31 of Set 16 | sokol
# Processing Record 32 of Set 16 | lubyany
# Processing Record 33 of Set 16 | esmeraldas
# Processing Record 34 of Set 16 | marapanim
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 724

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Uray  60.1247   64.7758     46.99        91          56
# 1        Vanimo  -2.6741  141.3028     77.07        90          99
# 2     Caravelas -17.7125  -39.2481     79.75        64          97
# 3        Loreto  22.2667 -101.9667     71.15        44          23
# 4     Saskylakh  71.9167  114.0833     21.52        96         100
# 5          Hilo  19.7297 -155.0900     87.28        67          20
# 6    Zhezkazgan  47.8043   67.7144     44.26        25           0
# 7       Rikitea -23.1203 -134.9692     69.12        66          57
# 8        Broome  42.2506  -75.8330     56.17        72         100
# 9  Ponta Do Sol  32.6667  -17.1000     72.23        81           7
#
#    Wind Speed Country      Description
# 0        5.57      RU    broken clouds
# 1        5.08      PG  overcast clouds
# 2       13.02      BR  overcast clouds
# 3        5.30      MX       few clouds
# 4        4.23      RU       light snow
# 5        5.01      US       few clouds
# 6       13.09      KZ        clear sky
# 7       25.23      PF    broken clouds
# 8       13.80      US  overcast clouds
# 9        3.62      PT        clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
city_data_df.rename(columns = {'Description':'Current Description'}, inplace = True)

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Uray      RU  60.1247   64.7758     46.99        91          56
# 1        Vanimo      PG  -2.6741  141.3028     77.07        90          99
# 2     Caravelas      BR -17.7125  -39.2481     79.75        64          97
# 3        Loreto      MX  22.2667 -101.9667     71.15        44          23
# 4     Saskylakh      RU  71.9167  114.0833     21.52        96         100
# 5          Hilo      US  19.7297 -155.0900     87.28        67          20
# 6    Zhezkazgan      KZ  47.8043   67.7144     44.26        25           0
# 7       Rikitea      PF -23.1203 -134.9692     69.12        66          57
# 8        Broome      US  42.2506  -75.8330     56.17        72         100
# 9  Ponta Do Sol      PT  32.6667  -17.1000     72.23        81           7
#
#    Wind Speed Current Description
# 0        5.57       broken clouds
# 1        5.08     overcast clouds
# 2       13.02     overcast clouds
# 3        5.30          few clouds
# 4        4.23          light snow
# 5        5.01          few clouds
# 6       13.09           clear sky
# 7       25.23       broken clouds
# 8       13.80     overcast clouds
# 9        3.62           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
